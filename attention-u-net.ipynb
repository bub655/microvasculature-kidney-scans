# %%
# %pip install torch

# %%
import torch
from torch.utils.data import Dataset
from torchvision import transforms
import tifffile as tiff
import cv2
import torch.nn as nn
import albumentations as A
import numpy as np
import os
import time
import torch.nn.functional as F
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !nvidia-smi
# Out:
# Mon Nov 27 15:56:03 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    40W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
base_path = '/kaggle/input/blood-vessel-segmentation/train'  

dataset = 'kidney_1_dense'

images_path = os.path.join(base_path, dataset, 'images')
labels_path = os.path.join(base_path, dataset, 'labels')

image_files = sorted([os.path.join(images_path, f) for f in os.listdir(images_path) if f.endswith('.tif')])
label_files = sorted([os.path.join(labels_path, f) for f in os.listdir(labels_path) if f.endswith('.tif')])

def show_images(images,titles= None, cmap='gray'):
    n = len(images)
    fig, axes = plt.subplots(1, n, figsize=(20, 10))
    if not isinstance(axes, np.ndarray):
        axes = [axes]
    for idx, ax in enumerate(axes):
        ax.imshow(images[idx], cmap=cmap)
        if titles:
            ax.set_title(titles[idx])
        ax.axis('off')
    plt.tight_layout()
    plt.show()

first_image = tiff.imread(image_files[981])
first_label = tiff.imread(label_files[981])

show_images([first_image, first_label], titles=['First Image', 'First Label'])

# %%
class CustomDataset(Dataset):
    def __init__(self, image_files, mask_files, input_size=(256, 256), augmentation_transforms=None):
        self.image_files = image_files
        self.mask_files = mask_files
        self.input_size = input_size
        self.augmentation_transforms = augmentation_transforms

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
       
        image_path = self.image_files[idx]
        mask_path = self.mask_files[idx]

        image = preprocess_image(image_path)
        mask = preprocess_mask(mask_path)

        if self.augmentation_transforms:
            image, mask = self.augmentation_transforms(image, mask)

        return image, mask

# %%
def preprocess_image(path):
    
    img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    img = np.tile(img[...,None],[1, 1, 3]) 
    img = img.astype('float32') 
    mx = np.max(img)
    if mx:
        img/=mx 
        
    img = np.transpose(img, (2, 0, 1))
    img_ten = torch.tensor(img)
    return img_ten

# %%
def preprocess_mask(path):
    
    msk = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    msk = msk.astype('float32')
    msk/=255.0
    msk_ten = torch.tensor(msk)
    
    return msk_ten

# %%
def augment_image(image, mask):
    
    image_np = image.permute(1, 2, 0).numpy()
    mask_np = mask.numpy()

    transform = A.Compose([
        A.Resize(256,256, interpolation=cv2.INTER_NEAREST),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),
        A.RandomCrop(height=256, width=256, always_apply=True),
        A.RandomBrightness(p=1),
        A.OneOf(
            [
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),
    
    ])

    augmented = transform(image=image_np, mask=mask_np)
    augmented_image, augmented_mask = augmented['image'], augmented['mask']

    augmented_image = torch.tensor(augmented_image, dtype=torch.float32).permute(2, 0, 1)
    augmented_mask = torch.tensor(augmented_mask, dtype=torch.float32)

    return augmented_image, augmented_mask

# %%
base_path = '/kaggle/input/blood-vessel-segmentation/train'  

dataset = 'kidney_1_dense'

images_path = os.path.join(base_path, dataset, 'images')
labels_path = os.path.join(base_path, dataset, 'labels')

image_files = sorted([os.path.join(images_path, f) for f in os.listdir(images_path) if f.endswith('.tif')])
label_files = sorted([os.path.join(labels_path, f) for f in os.listdir(labels_path) if f.endswith('.tif')])

# %%
train_image_files, val_image_files, train_mask_files, val_mask_files = train_test_split(
    image_files, label_files, test_size=0.2, random_state=42)

# %%
train_dataset = CustomDataset(train_image_files, train_mask_files, augmentation_transforms=augment_image)
val_dataset = CustomDataset(val_image_files, val_mask_files, augmentation_transforms=augment_image)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=8, shuffle=False)

# %%
for batch_idx, (batch_images, batch_masks) in enumerate(train_dataloader):
    print("Batch", batch_idx + 1)
    print("Image batch shape:", batch_images.shape)
    print("Mask batch shape:", batch_masks.shape)
    
    for image, mask, image_path, mask_path in zip(batch_images, batch_masks, train_image_files, train_mask_files):
       
        image = image.permute((1, 2, 0)).numpy()*255.0
        image = image.astype('uint8')
        mask = (mask*255).numpy().astype('uint8')
        
        image_filename = os.path.basename(image_path)
        mask_filename = os.path.basename(mask_path)
        
        plt.figure(figsize=(15, 10))
        
        plt.subplot(2, 4, 1)
        plt.imshow(image, cmap='gray')
        plt.title(f"Original Image - {image_filename}")
        
        plt.subplot(2, 4, 2)
        plt.imshow(mask, cmap='gray')
        plt.title(f"Mask Image - {mask_filename}")
        
        plt.tight_layout()
        plt.show()
    break
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/transforms.py:1258: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# Batch 1
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])

# %%
for batch_idx, (batch_images, batch_masks) in enumerate(train_dataloader):
    print("Batch", batch_idx + 1)
    print("Image batch shape:", batch_images.shape)
    print("Mask batch shape:", batch_masks.shape)
# Out:
# Batch 1
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 2
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 3
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 4
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 5
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 6
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 7
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 8
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 9
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 10
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 11
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 12
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 13
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 14
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 15
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 16
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 17
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 18
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 19
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 20
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 21
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 22
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 23
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 24
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 25
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 26
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 27
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 28
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 29
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 30
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 31
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 32
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 33
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 34
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 35
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 36
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 37
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 38
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 39
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 40
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 41
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 42
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 43
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 44
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 45
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 46
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 47
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 48
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 49
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 50
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 51
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 52
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 53
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 54
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 55
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 56
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 57
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 58
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 59
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 60
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 61
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 62
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 63
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 64
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 65
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 66
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 67
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 68
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 69
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 70
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 71
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 72
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 73
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 74
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 75
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 76
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 77
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 78
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 79
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 80
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 81
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 82
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 83
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 84
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 85
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 86
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 87
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 88
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 89
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 90
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 91
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 92
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 93
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 94
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 95
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 96
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 97
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 98
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 99
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 100
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 101
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 102
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 103
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 104
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 105
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 106
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 107
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 108
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 109
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 110
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 111
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 112
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 113
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 114
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 115
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 116
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 117
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 118
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 119
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 120
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 121
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 122
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 123
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 124
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 125
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 126
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 127
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 128
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 129
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 130
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 131
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 132
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 133
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 134
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 135
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 136
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 137
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 138
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 139
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 140
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 141
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 142
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 143
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 144
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 145
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 146
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 147
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 148
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 149
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 150
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 151
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 152
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 153
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 154
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 155
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 156
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 157
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 158
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 159
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 160
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 161
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 162
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 163
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 164
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 165
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 166
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 167
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 168
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 169
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 170
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 171
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 172
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 173
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 174
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 175
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 176
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 177
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 178
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 179
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 180
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 181
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 182
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 183
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 184
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 185
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 186
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 187
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 188
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 189
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 190
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 191
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 192
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 193
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 194
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 195
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 196
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 197
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 198
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 199
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 200
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 201
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 202
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 203
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 204
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 205
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 206
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 207
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 208
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 209
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 210
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 211
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 212
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 213
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 214
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 215
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 216
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 217
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 218
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 219
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 220
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 221
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 222
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 223
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 224
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 225
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 226
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 227
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 228
# Image batch shape: torch.Size([7, 3, 256, 256])
# Mask batch shape: torch.Size([7, 256, 256])

# %%
for batch_idx, (batch_images, batch_masks) in enumerate(val_dataloader):
    print("Batch", batch_idx + 1)
    print("Image batch shape:", batch_images.shape)
    print("Mask batch shape:", batch_masks.shape)
# Out:
# Batch 1
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 2
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 3
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 4
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 5
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 6
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 7
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 8
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 9
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 10
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 11
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 12
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 13
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 14
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 15
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 16
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 17
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 18
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 19
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 20
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 21
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 22
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 23
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 24
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 25
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 26
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 27
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 28
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 29
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 30
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 31
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 32
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 33
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 34
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 35
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 36
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 37
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 38
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 39
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 40
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 41
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 42
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 43
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 44
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 45
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 46
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 47
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 48
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 49
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 50
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 51
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 52
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 53
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 54
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 55
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 56
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])
# Batch 57
# Image batch shape: torch.Size([8, 3, 256, 256])
# Mask batch shape: torch.Size([8, 256, 256])

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
class ConvBlock(nn.Module):

    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=True),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=True),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class UpConv(nn.Module):

    def __init__(self, in_channels, out_channels):
        super(UpConv, self).__init__()

        self.up = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=True),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.up(x)
        return x


class AttentionBlock(nn.Module):
    """Attention block with learnable parameters"""

    def __init__(self, F_g, F_l, n_coefficients):
        """
        :param F_g: number of feature maps (channels) in previous layer
        :param F_l: number of feature maps in corresponding encoder layer, transferred via skip connection
        :param n_coefficients: number of learnable multi-dimensional attention coefficients
        """
        super(AttentionBlock, self).__init__()

        self.W_gate = nn.Sequential(
            nn.Conv2d(F_g, n_coefficients, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(n_coefficients)
        )

        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, n_coefficients, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(n_coefficients)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(n_coefficients, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )

        self.relu = nn.ReLU(inplace=True)

    def forward(self, gate, skip_connection):
        """
        :param gate: gating signal from previous layer
        :param skip_connection: activation from corresponding encoder layer
        :return: output activations
        """
        g1 = self.W_gate(gate)
        x1 = self.W_x(skip_connection)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        out = skip_connection * psi
        return out


class AttentionUNet(nn.Module):

    def __init__(self, img_ch=3, output_ch=1):
        super(AttentionUNet, self).__init__()

        self.MaxPool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.Conv1 = ConvBlock(img_ch, 64)
        self.Conv2 = ConvBlock(64, 128)
        self.Conv3 = ConvBlock(128, 256)
        self.Conv4 = ConvBlock(256, 512)
        self.Conv5 = ConvBlock(512, 1024)

        self.Up5 = UpConv(1024, 512)
        self.Att5 = AttentionBlock(F_g=512, F_l=512, n_coefficients=256)
        self.UpConv5 = ConvBlock(1024, 512)

        self.Up4 = UpConv(512, 256)
        self.Att4 = AttentionBlock(F_g=256, F_l=256, n_coefficients=128)
        self.UpConv4 = ConvBlock(512, 256)

        self.Up3 = UpConv(256, 128)
        self.Att3 = AttentionBlock(F_g=128, F_l=128, n_coefficients=64)
        self.UpConv3 = ConvBlock(256, 128)

        self.Up2 = UpConv(128, 64)
        self.Att2 = AttentionBlock(F_g=64, F_l=64, n_coefficients=32)
        self.UpConv2 = ConvBlock(128, 64)

        self.Conv = nn.Conv2d(64, output_ch, kernel_size=1, stride=1, padding=0)

    def forward(self, x):
        """
        e : encoder layers
        d : decoder layers
        s : skip-connections from encoder layers to decoder layers
        """
        e1 = self.Conv1(x)

        e2 = self.MaxPool(e1)
        e2 = self.Conv2(e2)

        e3 = self.MaxPool(e2)
        e3 = self.Conv3(e3)

        e4 = self.MaxPool(e3)
        e4 = self.Conv4(e4)

        e5 = self.MaxPool(e4)
        e5 = self.Conv5(e5)

        d5 = self.Up5(e5)

        s4 = self.Att5(gate=d5, skip_connection=e4)
        d5 = torch.cat((s4, d5), dim=1) 
        d5 = self.UpConv5(d5)

        d4 = self.Up4(d5)
        s3 = self.Att4(gate=d4, skip_connection=e3)
        d4 = torch.cat((s3, d4), dim=1)
        d4 = self.UpConv4(d4)

        d3 = self.Up3(d4)
        s2 = self.Att3(gate=d3, skip_connection=e2)
        d3 = torch.cat((s2, d3), dim=1)
        d3 = self.UpConv3(d3)

        d2 = self.Up2(d3)
        s1 = self.Att2(gate=d2, skip_connection=e1)
        d2 = torch.cat((s1, d2), dim=1)
        d2 = self.UpConv2(d2)

        out = self.Conv(d2)

        return out

# %%
def dice_coeff(prediction, target):

    mask = np.zeros_like(prediction)
    mask[prediction >= 0.5] = 1

    inter = np.sum(mask * target)
    union = np.sum(mask) + np.sum(target)
    epsilon = 1e-6
    result = np.mean(2 * inter / (union + epsilon))
    return result

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):

    def __init__(self, gamma=0, size_average=None, ignore_index=-100,
                 reduce=None, balance_param=1.0):
        super(FocalLoss, self).__init__(size_average)
        self.gamma = gamma
        self.size_average = size_average
        self.ignore_index = ignore_index
        self.balance_param = balance_param

    def forward(self, input, target):
        
        assert len(input.shape) == len(target.shape)
        assert input.size(0) == target.size(0)
        assert input.size(1) == target.size(1)

        logpt = - F.binary_cross_entropy_with_logits(input, target)
        pt = torch.exp(logpt)

        focal_loss = -((1 - pt) ** self.gamma) * logpt
        balanced_focal_loss = self.balance_param * focal_loss
        return balanced_focal_loss

# %%
dataloaders = {
    'training': train_dataloader,
    'test': val_dataloader
}

# %%
def train_and_test(model, dataloaders, optimizer, criterion, num_epochs=100, show_images=False):
    since = time.time()
    best_loss = 1e10
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)

    fieldnames = ['epoch', 'training_loss', 'test_loss', 'training_dice_coeff', 'test_dice_coeff']
    train_epoch_losses = []
    test_epoch_losses = []
    for epoch in range(1, num_epochs + 1):

        print(f'Epoch {epoch}/{num_epochs}')
        print('-' * 10)
        
        batchsummary = {a: [0] for a in fieldnames}
        batch_train_loss = 0.0
        batch_test_loss = 0.0

        for phase in ['training', 'test']:
            if phase == 'training':
                model.train()  
            else:
                model.eval() 

            for sample in iter(dataloaders[phase]):

                if show_images:
                    grid_img = make_grid(sample[0])
                    grid_img = grid_img.permute(1, 2, 0)
                    plt.imshow(grid_img)
                    plt.show()

                inputs = sample[0].to(device)
                masks = sample[1].to(device)
                
                masks = masks.unsqueeze(1)
                
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'training'):
                    outputs = model(inputs)

                    loss = criterion(outputs, masks)

                    y_pred = outputs.data.cpu().numpy().ravel()
                    y_true = masks.data.cpu().numpy().ravel()

                    batchsummary[f'{phase}_dice_coeff'].append(dice_coeff(y_pred, y_true))

                    if phase == 'training':
                        loss.backward()
                        optimizer.step()

                        batch_train_loss += loss.item() * sample[0].size(0)

                    else:
                        batch_test_loss += loss.item() * sample[0].size(0)

            if phase == 'training':
                epoch_train_loss = batch_train_loss / len(dataloaders['training'])
                train_epoch_losses.append(epoch_train_loss)
            else:
                epoch_test_loss = batch_test_loss / len(dataloaders['test'])
                test_epoch_losses.append(epoch_test_loss)

            batchsummary['epoch'] = epoch
            
            print('{} Loss: {:.4f}'.format(phase, loss))

        best_loss = np.max(batchsummary['test_dice_coeff'])
        for field in fieldnames[3:]:
            batchsummary[field] = np.mean(batchsummary[field])
        print(
            f'\t\t\t train_dice_coeff: {batchsummary["training_dice_coeff"]}, test_dice_coeff: {batchsummary["test_dice_coeff"]}')

    print('Best dice coefficient: {:4f}'.format(best_loss))

    return model, train_epoch_losses, test_epoch_losses

# %%
epochs = 25

def train():
    model = AttentionUNet()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = FocalLoss(gamma=2)

    trained_model, train_epoch_losses, test_epoch_losses = train_and_test(model, dataloaders, optimizer, criterion, num_epochs=epochs)

    return trained_model, train_epoch_losses, test_epoch_losses


trained_model, train_epoch_losses, test_epoch_losses = train()
# Out:
# Epoch 1/25
# ----------
# training Loss: 0.0124
# test Loss: 0.0114
# 			 train_dice_coeff: 9.216410763910845e-05, test_dice_coeff: 0.0
# Epoch 2/25
# ----------
# training Loss: 0.0065
# test Loss: 0.0058
# 			 train_dice_coeff: 3.5985267616604637e-06, test_dice_coeff: 2.605914121607774e-05
# Epoch 3/25
# ----------
# training Loss: 0.0042
# test Loss: 0.0031
# 			 train_dice_coeff: 3.2418799001138054e-06, test_dice_coeff: 0.0
# Epoch 4/25
# ----------
# training Loss: 0.0025
# test Loss: 0.0022
# 			 train_dice_coeff: 0.0, test_dice_coeff: 0.0
# Epoch 5/25
# ----------
# training Loss: 0.0018
# test Loss: 0.0016
# 			 train_dice_coeff: 0.0, test_dice_coeff: 0.0
# Epoch 6/25
# ----------
# training Loss: 0.0010
# test Loss: 0.0012
# 			 train_dice_coeff: 0.0, test_dice_coeff: 3.1592083016758254e-05
# Epoch 7/25
# ----------
# training Loss: 0.0009
# test Loss: 0.0009
# 			 train_dice_coeff: 0.0, test_dice_coeff: 0.0
# Epoch 8/25
# ----------
# training Loss: 0.0007
# test Loss: 0.0007
# 			 train_dice_coeff: 0.0, test_dice_coeff: 0.0
# Epoch 9/25
# ----------
# training Loss: 0.0006
# test Loss: 0.0005
# 			 train_dice_coeff: 0.0, test_dice_coeff: 0.0
# Epoch 10/25
# ----------
# training Loss: 0.0004
# test Loss: 0.0004
# 			 train_dice_coeff: 5.135310087934406e-05, test_dice_coeff: 0.0
# Epoch 11/25
# ----------
# training Loss: 0.0004
# test Loss: 0.0003
# 			 train_dice_coeff: 0.003298931514472621, test_dice_coeff: 0.0046756776611283895
# Epoch 12/25
# ----------
# training Loss: 0.0003
# test Loss: 0.0003
# 			 train_dice_coeff: 0.04299930705331096, test_dice_coeff: 0.11846173705205845
# Epoch 13/25
# ----------
# training Loss: 0.0002
# test Loss: 0.0002
# 			 train_dice_coeff: 0.18532962324699934, test_dice_coeff: 0.22443824846764282
# Epoch 14/25
# ----------
# training Loss: 0.0002
# test Loss: 0.0002
# 			 train_dice_coeff: 0.3282218626689497, test_dice_coeff: 0.3025702384999189
# Epoch 15/25
# ----------
# training Loss: 0.0002
# test Loss: 0.0002
# 			 train_dice_coeff: 0.4296078549871959, test_dice_coeff: 0.3830797210999378
# Epoch 16/25
# ----------
# training Loss: 0.0002
# test Loss: 0.0001
# 			 train_dice_coeff: 0.46636003256404857, test_dice_coeff: 0.43587216204633095
# Epoch 17/25
# ----------
# training Loss: 0.0001
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5047005150189829, test_dice_coeff: 0.468524394539927
# Epoch 18/25
# ----------
# training Loss: 0.0001
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5182885465479152, test_dice_coeff: 0.4974202931509683
# Epoch 19/25
# ----------
# training Loss: 0.0001
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5222131900666163, test_dice_coeff: 0.4778294341240057
# Epoch 20/25
# ----------
# training Loss: 0.0001
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5388052133059654, test_dice_coeff: 0.5207612473643557
# Epoch 21/25
# ----------
# training Loss: 0.0001
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5461760227543633, test_dice_coeff: 0.46905767671256093
# Epoch 22/25
# ----------
# training Loss: 0.0000
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5521134889902118, test_dice_coeff: 0.5517887152456324
# Epoch 23/25
# ----------
# training Loss: 0.0000
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5762840281254201, test_dice_coeff: 0.5487480547725467
# Epoch 24/25
# ----------
# training Loss: 0.0000
# test Loss: 0.0001
# 			 train_dice_coeff: 0.5609234001440244, test_dice_coeff: 0.5124152191763456
# Epoch 25/25
# ----------
# training Loss: 0.0000
# test Loss: 0.0000
# 			 train_dice_coeff: 0.5766044132077257, test_dice_coeff: 0.5184548205009725
# Best dice coefficient: 0.740942

# %%
torch.save(trained_model.state_dict(), 'trained_model.pth')

# %%
train_plot, = plt.plot(range(1, len(train_epoch_losses) + 1), train_epoch_losses, label='train loss')
test_plot, = plt.plot(range(1, len(test_epoch_losses) + 1), test_epoch_losses, label='test loss')
plt.legend(handles=[train_plot, test_plot])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Test Loss Over Epochs')
plt.show()

# %%
train_plot, = plt.plot(range(len(train_epoch_losses)-15), train_epoch_losses[15:], label='train loss')
test_plot, = plt.plot(range(len(test_epoch_losses)-15), test_epoch_losses[15:], label='test loss')
plt.legend(handles=[train_plot, test_plot])
plt.show()
